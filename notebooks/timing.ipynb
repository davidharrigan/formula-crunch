# %%
from IPython.display import display, Markdown, HTML
import pandas as pd
import numpy as np
import fastf1 as ff1
from scrape.core.session import get_session

import logging
logging.basicConfig(level=logging.DEBUG)

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

YEAR = 2022
RACE = "Austria"

ff1.Cache.enable_cache("./data/cache")

session = get_session(YEAR, RACE, "Race")
session.load(telemetry=True, laps=True, messages=True, weather=False, timing=True)
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Race [v2.2.9]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '1', '44', '63', '31', '47', '4', '20', '3', '14', '77', '23', '18', '24', '10', '22', '5', '55', '6', '11']
# timing         INFO 	Fetching timing stream data...
# timing         INFO 	Parsing timing stream data...
# session        INFO 	Processing timing data...

# %%
session._load_timing_data()
session.timing_data[240:340]
# Out:
# timing         INFO 	Fetching timing stream data...
# timing         INFO 	Parsing timing stream data...
# session        INFO 	Processing timing data...
#                       Time  Position GapToLeader IntervalToPositionAhead  \
# 288 0 days 01:14:06.778000         1         NaN                     NaN
# 289 0 days 01:14:10.837000         1         NaN                     NaN
# 290 0 days 01:14:13.896000         1         NaN                     NaN
# 291 0 days 01:14:16.543000         1         NaN                     NaN
# 292 0 days 01:14:19.498000         1         NaN                     NaN
# 293 0 days 01:14:21.513000         1         NaN                     NaN
# 294 0 days 01:14:26.959000         1         NaN                     NaN
# 295 0 days 01:14:31.775000         1         NaN                     NaN
# 296 0 days 01:14:34.143000         1         NaN                     NaN
# 297 0 days 01:14:41.259000         1         NaN                     NaN
# ...

# %%
session._load_timing_data()
df = session.timing_data


# display(df[:50])
# sainz = df[df["DriverNumber"] == "1"][
#     [
#         "Time",
#         "DriverNumber",
#         "Position",
#         "LapNumber",
#         "LastSectorSegmentNumber",
#         "LastSectorSegmentStatus",
#         "PitIn",
#         "PitOut",
#         "IntervalToPositionAhead",
#         "Status",
#     ]
# ]
# 
# # display(sainz[75:100])
# # display(sainz[(~sainz["LastSectorSegmentStatus"].isnull())][:100])
# display(sainz["Status"].unique())
# sainz = sainz[sainz["LastSectorSegmentStatus"] == 2064]
# # display(sainz[sainz.LapNumber == "26"])
# display(sainz)

# display(sainz[(sainz["LapNumber"].isin(["53", "54"])) & (~sainz["LastSectorSegmentStatus"].isnull())])

display(df[df["DriverNumber"] == "1"][200:300])
# display(df[(df["DriverNumber"] == "1") & (df["LapNumber"] == 12)])
# Out:
# api            INFO 	Using cached data for get_timing_data
# session        INFO 	Processing timing data...
#                       Time  Position GapToLeader IntervalToPositionAhead  \
# 200 0 days 01:09:30.731000         1         NaN                     NaN
# 201 0 days 01:09:32.830000         1         NaN                     NaN
# 202 0 days 01:09:35.973000         1         NaN                     NaN
# 203 0 days 01:09:37.943000         1         NaN                     NaN
# 204 0 days 01:09:43.386000         1         NaN                     NaN
# 205 0 days 01:09:48.103000         1         NaN                     NaN
# 206 0 days 01:09:50.424000         1         NaN                     NaN
# 207 0 days 01:09:57.518000         1         NaN                     NaN
# 208 0 days 01:10:01.875000         1         NaN                     NaN
# 209 0 days 01:10:07.368000         1         NaN                     NaN
# ...

# %%
df.add_lap_numbers()
display(df)
